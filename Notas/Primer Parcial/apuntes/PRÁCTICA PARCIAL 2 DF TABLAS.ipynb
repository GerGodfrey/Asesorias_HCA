# %%
# %pylab
import pandas as pd
# %matplotlib inline
# Out:
# Using matplotlib backend: Qt5Agg
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# **Ejercicio 1**
#
#
# Crear un diccionario con las siguientes llaves y 20 datos
# * Nombre
# * Edad
# * Semestre
# * Promedio

# %%
nom="Adaya Isui Andrés Jesús Alberto Ana Paola Karla Mariana Fernanada"
no=nom.split()*2
ed=list(randint(18,23,20))
sem=list(randint(1,11,20))
prom=list(randint(3,11,20))
dic1={"Nombre":no,
     "Edad":ed,
     "Semestre":sem,
     "Promedio":prom}
print(dic1)
# Out:
# {'Nombre': ['Adaya', 'Isui', 'Andrés', 'Jesús', 'Alberto', 'Ana', 'Paola', 'Karla', 'Mariana', 'Fernanada', 'Adaya', 'Isui', 'Andrés', 'Jesús', 'Alberto', 'Ana', 'Paola', 'Karla', 'Mariana', 'Fernanada'], 'Edad': [20, 20, 18, 22, 21, 19, 19, 19, 19, 19, 22, 19, 18, 19, 21, 22, 22, 22, 22, 22], 'Semestre': [2, 7, 7, 9, 4, 8, 3, 10, 5, 8, 1, 9, 5, 6, 8, 3, 9, 5, 2, 8], 'Promedio': [3, 6, 5, 3, 10, 4, 8, 8, 8, 6, 4, 3, 8, 3, 6, 10, 10, 5, 7, 4]}

# %% [markdown]
# **Ejercicio 2**
#
# * convertir el diccionario en una DataFrame

# %%
df1=pd.DataFrame(dic1)
df1
# Out:
#        Nombre  Edad  Semestre  Promedio
# 0       Adaya    20         2         3
# 1        Isui    20         7         6
# 2      Andrés    18         7         5
# 3       Jesús    22         9         3
# 4     Alberto    21         4        10
# 5         Ana    19         8         4
# 6       Paola    19         3         8
# 7       Karla    19        10         8
# 8     Mariana    19         5         8
# 9   Fernanada    19         8         6
# 10      Adaya    22         1         4
# 11       Isui    19         9         3
# 12     Andrés    18         5         8
# 13      Jesús    19         6         3
# 14    Alberto    21         8         6
# 15        Ana    22         3        10
# 16      Paola    22         9        10
# 17      Karla    22         5         5
# 18    Mariana    22         2         7
# 19  Fernanada    22         8         4

# %%
#ordenar de forma ascendente por nombre
df1.sort_values(by="Nombre")
# Out:
#        Nombre  Edad  Semestre  Promedio
# 0       Adaya    20         2         3
# 10      Adaya    22         1         4
# 14    Alberto    21         8         6
# 4     Alberto    21         4        10
# 15        Ana    22         3        10
# 5         Ana    19         8         4
# 2      Andrés    18         7         5
# 12     Andrés    18         5         8
# 9   Fernanada    19         8         6
# 19  Fernanada    22         8         4
# 11       Isui    19         9         3
# 1        Isui    20         7         6
# 13      Jesús    19         6         3
# 3       Jesús    22         9         3
# 7       Karla    19        10         8
# 17      Karla    22         5         5
# 18    Mariana    22         2         7
# 8     Mariana    19         5         8
# 6       Paola    19         3         8
# 16      Paola    22         9        10

# %%
df1.sort_values(by="Edad")
# Out:
#        Nombre  Edad  Semestre  Promedio
# 2      Andrés    18         7         5
# 12     Andrés    18         5         8
# 9   Fernanada    19         8         6
# 13      Jesús    19         6         3
# 11       Isui    19         9         3
# 5         Ana    19         8         4
# 6       Paola    19         3         8
# 7       Karla    19        10         8
# 8     Mariana    19         5         8
# 0       Adaya    20         2         3
# 1        Isui    20         7         6
# 4     Alberto    21         4        10
# 14    Alberto    21         8         6
# 10      Adaya    22         1         4
# 3       Jesús    22         9         3
# 15        Ana    22         3        10
# 16      Paola    22         9        10
# 17      Karla    22         5         5
# 18    Mariana    22         2         7
# 19  Fernanada    22         8         4

# %%
df1.sort_values(by="Nombre",ascending=False)
# Out:
#        Nombre  Edad  Semestre  Promedio
# 16      Paola    22         9        10
# 6       Paola    19         3         8
# 8     Mariana    19         5         8
# 18    Mariana    22         2         7
# 17      Karla    22         5         5
# 7       Karla    19        10         8
# 3       Jesús    22         9         3
# 13      Jesús    19         6         3
# 1        Isui    20         7         6
# 11       Isui    19         9         3
# 19  Fernanada    22         8         4
# 9   Fernanada    19         8         6
# 12     Andrés    18         5         8
# 2      Andrés    18         7         5
# 5         Ana    19         8         4
# 15        Ana    22         3        10
# 4     Alberto    21         4        10
# 14    Alberto    21         8         6
# 0       Adaya    20         2         3
# 10      Adaya    22         1         4

# %%
df1.sort_values(by=["Nombre","Edad","Semestre"])
# Out:
#        Nombre  Edad  Semestre  Promedio
# 0       Adaya    20         2         3
# 10      Adaya    22         1         4
# 4     Alberto    21         4        10
# 14    Alberto    21         8         6
# 5         Ana    19         8         4
# 15        Ana    22         3        10
# 12     Andrés    18         5         8
# 2      Andrés    18         7         5
# 9   Fernanada    19         8         6
# 19  Fernanada    22         8         4
# 11       Isui    19         9         3
# 1        Isui    20         7         6
# 13      Jesús    19         6         3
# 3       Jesús    22         9         3
# 7       Karla    19        10         8
# 17      Karla    22         5         5
# 8     Mariana    19         5         8
# 18    Mariana    22         2         7
# 6       Paola    19         3         8
# 16      Paola    22         9        10

# %%
df1.sort_values(by=["Nombre","Edad","Semestre"],ascending=False)
# Out:
#        Nombre  Edad  Semestre  Promedio
# 16      Paola    22         9        10
# 6       Paola    19         3         8
# 18    Mariana    22         2         7
# 8     Mariana    19         5         8
# 17      Karla    22         5         5
# 7       Karla    19        10         8
# 3       Jesús    22         9         3
# 13      Jesús    19         6         3
# 1        Isui    20         7         6
# 11       Isui    19         9         3
# 19  Fernanada    22         8         4
# 9   Fernanada    19         8         6
# 2      Andrés    18         7         5
# 12     Andrés    18         5         8
# 15        Ana    22         3        10
# 5         Ana    19         8         4
# 14    Alberto    21         8         6
# 4     Alberto    21         4        10
# 10      Adaya    22         1         4
# 0       Adaya    20         2         3

# %%
pwd
# Out:
# 'C:\\Users\\Dell Inspiron\\Documents\\PADRON WORKS'

# %% [markdown]
# **Ejercicio 3**
#
# * Obtén la cantidad de alumnos que reprobaron

# %%
# el query filtra la información
dfe3=df1.query('Promedio<6') #el query va con apostrofe '' y parantesis ()
dfe3
# Out:
#        Nombre  Edad  Semestre  Promedio
# 0       Adaya    20         2         3
# 2      Andrés    18         7         5
# 3       Jesús    22         9         3
# 5         Ana    19         8         4
# 10      Adaya    22         1         4
# 11       Isui    19         9         3
# 13      Jesús    19         6         3
# 17      Karla    22         5         5
# 19  Fernanada    22         8         4

# %%
len(dfe3)
# Out:
# 9

# %%
dfe3["Promedio"].count()
# Out:
# 9

# %%
dfe3.iloc[:,[0,3]] #si son columnas salteadas es doble corchte []
# Out:
#        Nombre  Promedio
# 0       Adaya         3
# 2      Andrés         5
# 3       Jesús         3
# 5         Ana         4
# 10      Adaya         4
# 11       Isui         3
# 13      Jesús         3
# 17      Karla         5
# 19  Fernanada         4

# %% [markdown]
# **Ejercicio 4**
#
# * Obtén la cantidad de alumnos inscritos por semestre y grafíquelos

# %%
dfe4=df1.groupby("Semestre")[["Semestre"]].count()
dfe4
# Out:
#           Semestre
# Semestre
# 1                1
# 2                2
# 3                2
# 4                1
# 5                3
# 6                1
# 7                2
# 8                4
# 9                3
# 10               1

# %%
title("Alumnos por semestre")
col="yellow red blue green orange"
cole=col.split()*2
dfe4["Semestre"].plot(kind="pie",colors=cole,autopct="%2.2f%%")
print("")

# %%
title("Alumnos por semestre")
col1="yellow red blue pink orange"
cole1=col.split()*2
xlabel("Semestre")
ylabel("Cantidad de alumnos")
dfe4["Semestre"].plot(kind="bar",color=cole1)
print("")

# %%
title("Alumnos por semestre")
col1="yellow red blue pink orange"
cole1=col.split()*2
xlabel("Semestre")
ylabel("Cantidad de alumnos")
dfe4["Semestre"].plot(kind="barh",color=cole1)
print("")

# %%
title("Alumnos por semestre")
xlabel("Semestre")
ylabel("Cantidad de alumnos")
dfe4["Semestre"].plot(kind="line",color="green")
print("")

# %% [markdown]
# **Ejercicio 5**
#
# * leer el archivo alumnos.xlsx con pandas y convertilo a una DataFrame

# %%
df2=pd.read_excel("alumnos.xlsx")
df2
# Out:
#         Nombre  Parcial1  Parcial2  ExaFinal  Tareas  Proyecto  CaliFinal
# 0     Alumno 1        10         3         9       5         8       7.14
# 1     Alumno 2         8        10         7       6         3       7.78
# 2     Alumno 3         7         7        10       7         3       7.60
# 3     Alumno 4         9         9         7       3         4       7.54
# 4     Alumno 5         3         8         8       4         9       6.26
# ..         ...       ...       ...       ...     ...       ...        ...
# 95   Alumno 96         6         8         6       7         8       6.78
# 96   Alumno 97         3         7         9       8        10       6.72
# 97   Alumno 98         5        10         7       3         4       6.70
# 98   Alumno 99         6         8         9       7         9       7.68
# 99  Alumno 100         9        10         4       4         4       7.08
#
# [100 rows x 7 columns]

# %%
df2.head(3)
# Out:
#      Nombre  Parcial1  Parcial2  ExaFinal  Tareas  Proyecto  CaliFinal
# 0  Alumno 1        10         3         9       5         8       7.14
# 1  Alumno 2         8        10         7       6         3       7.78
# 2  Alumno 3         7         7        10       7         3       7.60

# %% [markdown]
# **ejercicio 6**
# * Promedio del primer parcial

# %%
dfe6=df2["Parcial1"].mean()
dfe6
# Out:
# 6.45

# %%
dfe61=df2["Parcial2"].mean()
dfe61
# Out:
# 6.85

# %% [markdown]
# **ejercicio 7**
# * Obtén las calificaciones del Primer parcial de los siguientes alumnos:
# * Alumno10, Alumno20,Alumno65,Alumno90

# %%
df2.head(2)
# Out:
#      Nombre  Parcial1  Parcial2  ExaFinal  Tareas  Proyecto  CaliFinal
# 0  Alumno 1        10         3         9       5         8       7.14
# 1  Alumno 2         8        10         7       6         3       7.78

# %%
df2.iloc[[9,19,65,90],[0,1]]
# Out:
#        Nombre  Parcial1
# 9   Alumno 10         4
# 19  Alumno 20         4
# 65  Alumno 66         9
# 90  Alumno 91         7

# %% [markdown]
# **ejercicio 8**
# * Ordenar la DataFrame por el campo Parcial1 de forma ascendente

# %%
eje8=df2.sort_values(by="Parcial1")
eje8
# Out:
#        Nombre  Parcial1  Parcial2  ExaFinal  Tareas  Proyecto  CaliFinal
# 59  Alumno 60         3        10         7       5         4       6.34
# 27  Alumno 28         3         9         3       9        10       5.70
# 12  Alumno 13         3         8         8       7         9       6.56
# 91  Alumno 92         3         8        10       9         7       7.20
# 57  Alumno 58         3        10         9       5         8       7.14
# ..        ...       ...       ...       ...     ...       ...        ...
# 35  Alumno 36        10         8         4       3         8       6.94
# 63  Alumno 64        10         5         4       7         3       6.20
# 70  Alumno 71        10         6        10       6         3       8.06
# 29  Alumno 30        10         8         8       3        10       8.18
# 0    Alumno 1        10         3         9       5         8       7.14
#
# [100 rows x 7 columns]

# %%
#forma 2
eje81=df2.sort_values(by="Parcial1")
eje81.iloc[:,[0,1]]
# Out:
#        Nombre  Parcial1
# 59  Alumno 60         3
# 27  Alumno 28         3
# 12  Alumno 13         3
# 91  Alumno 92         3
# 57  Alumno 58         3
# ..        ...       ...
# 35  Alumno 36        10
# 63  Alumno 64        10
# 70  Alumno 71        10
# 29  Alumno 30        10
# 0    Alumno 1        10
#
# [100 rows x 2 columns]

# %% [markdown]
# **ejercicio 9**
# * Ordenar la DataFrame por el campo Tareas de forma descendente

# %%
df2.head(2)
# Out:
#      Nombre  Parcial1  Parcial2  ExaFinal  Tareas  Proyecto  CaliFinal
# 0  Alumno 1        10         3         9       5         8       7.14
# 1  Alumno 2         8        10         7       6         3       7.78

# %%
eje9=df2.sort_values(by="Tareas",ascending=False)
eje9.iloc[:,[0,4]]
# Out:
#        Nombre  Tareas
# 82  Alumno 83      10
# 52  Alumno 53      10
# 24  Alumno 25      10
# 30  Alumno 31      10
# 22  Alumno 23      10
# ..        ...     ...
# 36  Alumno 37       3
# 37  Alumno 38       3
# 49  Alumno 50       3
# 67  Alumno 68       3
# 50  Alumno 51       3
#
# [100 rows x 2 columns]

# %% [markdown]
# **ejercicio 10**
# * Ordenar la DataFrame por los campos Parcial1,Parcial2,ExaFinal,Tareas,Proyecto y CaliFinal

# %%
df2.head(3)
# Out:
#      Nombre  Parcial1  Parcial2  ExaFinal  Tareas  Proyecto  CaliFinal
# 0  Alumno 1        10         3         9       5         8       7.14
# 1  Alumno 2         8        10         7       6         3       7.78
# 2  Alumno 3         7         7        10       7         3       7.60

# %%
eje10=df2.sort_values(by=["Parcial1","Parcial2","ExaFinal","Tareas","Proyecto","CaliFinal"])
eje10
# Out:
#        Nombre  Parcial1  Parcial2  ExaFinal  Tareas  Proyecto  CaliFinal
# 53  Alumno 54         3         3         9      10         8       5.68
# 46  Alumno 47         3         6         7       5        10       5.58
# 96  Alumno 97         3         7         9       8        10       6.72
# 4    Alumno 5         3         8         8       4         9       6.26
# 12  Alumno 13         3         8         8       7         9       6.56
# ..        ...       ...       ...       ...     ...       ...        ...
# 70  Alumno 71        10         6        10       6         3       8.06
# 10  Alumno 11        10         7         7       6         3       7.50
# 35  Alumno 36        10         8         4       3         8       6.94
# 31  Alumno 32        10         8         7       3         7       7.72
# 29  Alumno 30        10         8         8       3        10       8.18
#
# [100 rows x 7 columns]

# %% [markdown]
# **ejercicio 11**
# * Obtén la distribución porcentual de calificaciones de tareas y grafícala

# %%
eje11=df2.groupby("Tareas")[["Tareas"]].count()
eje11
# Out:
#         Tareas
# Tareas
# 3           19
# 4            9
# 5           13
# 6            7
# 7           13
# 8            7
# 9           17
# 10          15

# %%
title("Porcentual de tareas")
colo2="red green orange blue"
cole2=colo2.split()*2
eje11["Tareas"].plot(kind="pie",colors=cole2,autopct="%2.2f%%")
print("")

# %% [markdown]
# **Ejercicio 12**
# * Obtenga a los alumnos que reprobaron el Parcial1 y aprobaron el Parcial2
# * muestre solamente la columna Nombre, Parcial1 y Parcial2

# %%
df2.head(2)
# Out:
#      Nombre  Parcial1  Parcial2  ExaFinal  Tareas  Proyecto  CaliFinal
# 0  Alumno 1        10         3         9       5         8       7.14
# 1  Alumno 2         8        10         7       6         3       7.78

# %%
eje12=df2.query('Parcial1<6 and Parcial2>=6')
eje12a=eje12.sort_values(by=["Parcial1","Parcial2"],ascending=False)
eje12.iloc[:,0:3]
# Out:
#        Nombre  Parcial1  Parcial2
# 4    Alumno 5         3         8
# 6    Alumno 7         3        10
# 9   Alumno 10         4         9
# 12  Alumno 13         3         8
# 15  Alumno 16         4         9
# 19  Alumno 20         4         9
# 23  Alumno 24         5         9
# 24  Alumno 25         4        10
# 26  Alumno 27         5         8
# 27  Alumno 28         3         9
# 30  Alumno 31         4         7
# 33  Alumno 34         4         6
# 44  Alumno 45         4        10
# 46  Alumno 47         3         6
# 48  Alumno 49         4        10
# 57  Alumno 58         3        10
# 59  Alumno 60         3        10
# 66  Alumno 67         3        10
# 72  Alumno 73         5         8
# 75  Alumno 76         4         6
# 81  Alumno 82         4         9
# 83  Alumno 84         5         7
# 85  Alumno 86         5         6
# 87  Alumno 88         5         9
# 91  Alumno 92         3         8
# 96  Alumno 97         3         7
# ...

# %% [markdown]
# **Ejercicio 13**
# * muestre en un Data Frame a los alumnos que aprobaron el Examen Final con más de 8
# * solamente muestre las columnas Nombre y ExaFinal
# * la columna ExaFinal debe estar ordenada de forma descendente

# %%
df2.head(2)
# Out:
#      Nombre  Parcial1  Parcial2  ExaFinal  Tareas  Proyecto  CaliFinal
# 0  Alumno 1        10         3         9       5         8       7.14
# 1  Alumno 2         8        10         7       6         3       7.78

# %%
eje13=df2.query('ExaFinal>8')
eje13a=eje13.sort_values(by="ExaFinal",ascending=False)
eje13a.iloc[:,[0,3]]
# Out:
#        Nombre  ExaFinal
# 70  Alumno 71        10
# 7    Alumno 8        10
# 14  Alumno 15        10
# 17  Alumno 18        10
# 91  Alumno 92        10
# 88  Alumno 89        10
# 85  Alumno 86        10
# 47  Alumno 48        10
# 50  Alumno 51        10
# 2    Alumno 3        10
# 80  Alumno 81        10
# 74  Alumno 75        10
# 0    Alumno 1         9
# 96  Alumno 97         9
# 94  Alumno 95         9
# 51  Alumno 52         9
# 65  Alumno 66         9
# 57  Alumno 58         9
# 53  Alumno 54         9
# 24  Alumno 25         9
# 21  Alumno 22         9
# 20  Alumno 21         9
# 19  Alumno 20         9
# 16  Alumno 17         9
# 98  Alumno 99         9

# %% [markdown]
# **Ejercicio 14**
# * Obtenga los alumnos que reprobaron la materia
# * Solo muestre el nombre del alumno y la columna CaliFinal

# %%
eje14=df2.query('CaliFinal<6')
eje14a=eje14.sort_values(by="CaliFinal")
eje14a.iloc[:,[0,6]]
# Out:
#        Nombre  CaliFinal
# 28  Alumno 29       4.18
# 33  Alumno 34       4.44
# 25  Alumno 26       4.68
# 93  Alumno 94       4.74
# 90  Alumno 91       4.76
# 75  Alumno 76       4.78
# 49  Alumno 50       4.80
# 43  Alumno 44       4.94
# 68  Alumno 69       5.02
# 62  Alumno 63       5.06
# 9   Alumno 10       5.08
# 36  Alumno 37       5.10
# 30  Alumno 31       5.28
# 34  Alumno 35       5.32
# 79  Alumno 80       5.34
# 83  Alumno 84       5.40
# 60  Alumno 61       5.40
# 69  Alumno 70       5.48
# 92  Alumno 93       5.52
# 71  Alumno 72       5.54
# 39  Alumno 40       5.56
# 46  Alumno 47       5.58
# 73  Alumno 74       5.64
# 55  Alumno 56       5.68
# 53  Alumno 54       5.68
# 27  Alumno 28       5.70
# 15  Alumno 16       5.72
# 78  Alumno 79       5.78
# 56  Alumno 57       5.82
# 45  Alumno 46       5.86
# 66  Alumno 67       5.98

# %% [markdown]
# **Ejercicio 15**
# * Obtenga los alumnos que aprobaron todos los exámenes, tareas y proyecto
# * Solo muestre el nombre del alumno y la columna CaliFinal
# * Grafíquelos utilizando una gráfica de líneas

# %%
df2.head(2)
# Out:
#      Nombre  Parcial1  Parcial2  ExaFinal  Tareas  Proyecto  CaliFinal
# 0  Alumno 1        10         3         9       5         8       7.14
# 1  Alumno 2         8        10         7       6         3       7.78

# %%
eje15=df2.query('Parcial1>=6 and Parcial2>=6 and ExaFinal>=6 and Tareas>=6 and Proyecto>=6')
eje15a=eje15.sort_values(by=["Parcial1","Parcial2", "ExaFinal", "Tareas", "Proyecto"])
eje15a.iloc[:,[0,6]]
# Out:
#        Nombre  CaliFinal
# 16  Alumno 17       7.26
# 95  Alumno 96       6.78
# 98  Alumno 99       7.68
# 88  Alumno 89       8.66
# 82  Alumno 83       7.80
# 22  Alumno 23       8.26
# 65  Alumno 66       9.16

# %%
title("Calificaciones aporbatorias")
ylabel("Alumnos")
xlabel("Calificaciones")
eje15a["CaliFinal"].plot(kind="line",color="blue")
print("")
